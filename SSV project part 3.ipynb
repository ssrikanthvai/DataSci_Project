# %% [markdown]
# You must also turn this in by posting it on Github so your peers can review it and messaging Dr. Melamed the link.
#
# Overall specifications
#
# •	Follow all instructions: This is not strictly a specification, but it is crucial to read the instructions and make sure you did not miss anything. Make sure to submit a Jupyter notebook to Gradescope and also to upload your notebook to Github (info on that to come). As well, check reproducibility. You can try to follow your own steps in a clean directory and see if it works.
#
# •	Overall clarity of writing and organization: The organization should be clear: each paragraph should be related to what the writer is trying to communicate; and the topic of each paragraph and how it relates to the rest should be easy to understand.
#
# •	As with previous Project components, you must get 80% in order to have a Satisfactory project.

# %% [markdown]
# 1. Introduction
# Please start with a short introduction that describes the goals of the research paper. This should just be 2-3 sentences so the peer reading your project does not start out feeling totally lost.

# %% [markdown]
# The authors of this paper are interested in phenotypic plasticity. They attempt to understand the effect of diet and Hedgehog(Hh) signaling in determining rates of bone deposition in cranial bones of fish. To do this they have looked at the bones of fish that have been consuming different diets and fish that are mutants for Hh and quantified the distance between where the bone was before the treatment and where it was after as a measure of bone deposition.

# %% [markdown]
# 2. Part 2: Relate research questions, data, and figures

# %% [markdown]
# •	2.1: Include the contents of Part 2. You must address all comments where you lost points. You do not need to get a perfect score on Part 2 to get a Satisfactory grade on this project but you must work to address all comments.

# %% [markdown]
# An observation is a fish for whom the species and genotype (in the case of zebrafish), the diet treatment and the rate of deposition of bone matrix is notes. There are the fish were grown in specific feeding conditions and the bone deposition rate were assessed through skeletal staining. The features are the species of fish, the treatment the fish was under and the bone deposition for different facial bones.
# They wanted to assess the effect of hedgehog signaling on bone deposition and the effect that diet can have on that. The three cichlid varieties used all have different alleles for ptch1 a downstream target of Hh. They had 2 possible hypotheses, the first was that the bone growth would vary at the same rate across treatments or that the bone growth would vary but at different rates.
# This data is appropriate because it has the treatments and the bone deposition rate in it and a comparison of the 2 will allow us to answer the question. You can ask whether different bones have differential bone growth, that is data they have (bone deposition rates of individual bones) but do not address in the paper.
#
#
# They have a summary table with the mean deposition rates for each bone in each species of fish. The depositon rate is the distance between the green and red region as shown in the figure.
# They also have a line graph comparing the bone deposition in the pelagic diet vs the benthic diet for the IOP bone in the different cichlid species and the zebrafish mutants.
# The line graph clearly shows how different species are affected differently by the diet change supporting their second hypothesis. We can conclude that the effect of Hh signaling on bone deposition rate is highly diet specific.
# I would like to see a violoin plot of the depostion rates of different bones with the rates on the y axis and the bones on the x axis to see visually how they compare to one another and to also see how much variation there is within the species and bone type.
#
# There are 2 datasets one for cichlids (67 rows, 16 columns) and one for zebrafish (149 rows, 7 rows). It is a csv file so the delimiter is a comma. Each row is a single fish and the columns are features like genotype, species, bone etc.

# %% [markdown]
# ![Picture1.png](attachment:07915d7c-16d7-40ff-ab98-14c9f0d9cd77.png)![Picture2.png](attachment:bc27ee5a-2280-40b4-85b9-a1e6f3c804a5.png)

# %% [markdown]
# 3. Part 3: data cleaning and exploration
# In this part of the project, you will load in the actual data files (this was not required for Part 2) and make a few summaries of them. You must provide your code to do all the steps and your peer must be able to reproduce the output you got by running your code without modifications. This is called a reproducible analysis.  You will not get credit for a section of code unless your results are reproducible without modifications to the code.

# %% [markdown]
# 3.1: Load and clean data
#
# o	Describe steps someone can take to obtain the data files you are working with. For example, provide the link to a the paper's supplementary Excel file, and explain that you opened it in excel and then saved it as a CSV file called "frogs.csv" in the same directory as the notebook (or whatever, as long as what you instruct them to do matches what your code is so your code works). ONLY IN RARE CASES: Only if you check with Dr. Melamed first, and you have some data that requires special permission to access, or some other big hassle to access, you can do this some alternate way. Your data should be directly downloadable from the source and not your personal shared folder.
#
# o	Provide code to read in all relevant data files into data frames. Explain your code and why you did it that way. Show the "head" (first few lines/rows/columns) of each data frame.
#
# o	If any cleaning steps were needed at this point, explain these cleaning steps. Otherwise, explain how you checked that the data frames were suitable for the further analyses.

# %% [markdown]
# DOI: 10.5061/dryad.jm63xsj7q

# %% [markdown]
# the data is available at the above doi it is an xlsx file when you download it. I downloaded the first sheet alone from that sheet to use for my analysis

# %%
import pandas as pd
import seaborn as sns

# %%
cichlids = pd.read_csv("Navon et al_project part 3.csv")
cichlids.head()
# Out:
#   Species Treatment Sp.Treat  Round  ID  scale 1  scale 2  scale 3  scale avg  \
# 0      LF       Ben   LF Ben      1   1    79.30    85.71    98.86  87.956667
# 1      LF       Ben   LF Ben      1   2    93.76   110.85    89.45  98.020000
# 2      LF       Ben   LF Ben      1   3    41.80    66.02    59.83  55.883333
# 3      LF       Ben   LF Ben      1   4    75.32    50.87    61.47  62.553333
# 4      LF       Ben   LF Ben      2   1     4.29     4.58     4.38   4.416667
#
#      iop post     iop ant    mand art       max2       max3          op  \
# 0  305.898728  367.383029   81.369369        NaN -78.461725  -47.960519
# 1  -88.251151 -106.854605   24.815036 -48.418334  74.816073   49.144771
# 2   84.327686   -0.595500   38.542403  96.143002        NaN  380.429998
# 3 -239.539150 -315.736194 -198.311370  26.016883        NaN -364.844160
# 4   -0.089391         NaN   -8.808907        NaN  24.475133   27.994921
#
#    premax asc
# 0         NaN
# 1  162.638438
# 2  251.030519
# ...

# %% [markdown]
# •	3.2: Describe data numerically
# o	Provide code to obtain the shape of the data files. Describe how this shape relates to the number of observations and the number of features. Be precise, such as "This data frame has 6000 rows which is the number 500 mice times the 2 treatments times the 6 time points per treatment".
# o	Pick two features to investigate. For each feature.
# 	Explain what you expect the "describe" function would output, based on your understanding of that features. How many observations have a recorded value of that feature and what is the average across observations?
# 	Run the "describe" function and compare the results to what you predicted.

# %%
cichlids.shape
# Out:
# (67, 16)

# %% [markdown]
# shape is (67,16) therefore there are 16 features which are measure of bone deposition and the treatment the fish were under and 67 observations which are individual fish from 3 different species undergoing one of 2 diet treatments whose bone deposition was assessed

# %% [markdown]
# I pick max2 which is the first wing of the maxilla and max 3 which is the second wing of the maxilla and i would be interested to see if the bone deopsition rate differed between these 2 bones. the describe function would output the mean bone deposition rate for each of those bones and the deposition rates that were found at differnet percentiles. max2 to has 51 values under it and max3 has 58 values under it. max2 has a mean pretty close to 0 and max3 is around -1

# %%
cichlids.describe()
# Out:
#            Round         ID     scale 1     scale 2     scale 3   scale avg  \
# count  67.000000  67.000000   67.000000   66.000000   63.000000   67.000000
# mean    1.537313   3.388060   46.701343   47.740606   45.668571   46.612189
# std     0.502369   1.774869   30.569368   31.818938   28.866305   29.763288
# min     1.000000   1.000000    1.090000    1.050000    1.770000    1.453333
# 25%     1.000000   2.000000   27.420000   25.785000   23.395000   26.755000
# 50%     2.000000   3.000000   37.640000   42.920000   44.260000   41.866667
# 75%     2.000000   5.000000   71.715000   70.027500   61.620000   69.198333
# max     2.000000   8.000000  116.630000  158.040000  128.050000  132.330000
#
#            iop post       iop ant      mand art          max2        max3  \
# count  6.500000e+01  5.800000e+01  6.200000e+01  5.100000e+01   58.000000
# mean   6.923069e-10 -8.620758e-11 -6.612905e-10  4.705881e-10   -0.929158
# ...

# %% [markdown]
# my prediction was pretty accurate but it is not informative to average out the whole column. That number will tend towards 0 beacuse it includes individuals who increased there bone size and decreased. For that they must be grouped by their diet and the difference between them must be calculated.

# %% [markdown]
# •	3.3: Visualizations. Make two visualizations, one for each of the features from in 3.2. They could be univariate visualizations (just the one feature) or more than one feature visualizations. For each one.
# o	Describe what kind of visualization you want to make, why this is appropriate for this feature and data set, and how the visualization will provide insight into the data.
# o	Provide code and explain your code to make the visualization.
# o	Interpret the visualization: compare it to the "describe" function output from 3.2, and explain what insight into the data you can make with the visualization.
# o	Describe how your visualization relates to one of the hypotheses or figures from the paper.
# For graded version: Include a summary of the peer comments that you used to improve your submission and how addressed the comments.

# %% [markdown]
# a scatter plot between the 2 can tell me whether their growth is associated with one another as in when max2 grows it is likely that max3 will also grow in size. This plot will therefore provide insight into how multiple bone can be linked to one another in function where is one changes the other must change as well.
# One of the figures i chose was a table that showed the mean bone deposition rate for different bone under different conditions. This table looks at each bone in isolation but my figure adds to that story to tlk about how different bones are connected to one another
# for this particular graph we would need a trend line to be certain of the relationship

# %%
sns.relplot(data=cichlids, 
            x='max2',
            y='max3')

# %% [markdown]
# A histogram comparing the growth of one bone type between 2 treatments. the line graph in the paper compares overall bone growth between treatments but this will allow us to verify if all the bones in the face follow that pattern or whether some bones are affected differently compared to the whole body. In this case we see that the means of both the treatments are near the same value which is the same as was seen in the line graph and the same as was seen in the  description done earlier.

# %%
sns.displot(data = cichlids, x = 'max2', hue = 'Treatment', kde = True)
